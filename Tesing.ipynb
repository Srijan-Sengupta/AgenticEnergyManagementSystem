# %%
from app.agent import graph
# !pip install grandalf
g = graph.build_graph()

print(graph.build_graph().get_graph().draw_ascii())
# Out:
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
#                                             +-----------+
#                                             | __start__ |
#                                             +-----------+
#                                                   *
#                                                   *
#                                                   *
#                                          +-----------------+
#                                          | classify_intent |..
#                                          +-----------------+  .......
#                                           ...                        ........
#                                         ..                                   .......
#                                       ..                                            .......
# ...
